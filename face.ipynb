# %%
#필요한 모듈설치

# !pip install pillow  
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\lee\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\lee\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\lee\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lee\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\lee\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lee\anaconda3\lib\site-packages (from requests) (2020.6.20)

# %%
# 첫줄은 사진관련
# 두번째 줄은 인터넷 연결 관련 모듈

# %%
import matplotlib.pyplot as plt #그림관련
import matplotlib.image as mpimg #사진관련

# %matplotlib inline

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "kydsTfNDsk_rwx6JKIFn"
client_secret = "dkJvfxVCG_"

#유명인
url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

#사진 한장은 2mb
# Out:
# {
#     "info": {
#         "size": {
#             "width": 600,
#             "height": 600
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "이나은",
#                 "confidence": 1.0
#             }
#         }
#     ]
# }

# %%
import requests  # 인터넷 연결

client_id = "kydsTfNDsk_rwx6JKIFn"
client_secret = "dkJvfxVCG_"

#얼굴정보
url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 600,
#             "height": 400
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 360,
#                 "y": 62,
#                 "width": 47,
#                 "height": 47
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 373,
#                     "y": 72
#                 },
#                 "rightEye": {
#                     "x": 393,
#                     "y": 73
#                 },
#                 "nose": {
#                     "x": 381,
#                     "y": 84
#                 },
#                 "leftMouth": {
#                     "x": 371,
#                     "y": 93
#                 },
#                 "rightMouth": {
#                     "x": 393,
#                     "y": 93
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 1.0
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.755652
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.887679
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999327
#             }
#         },
#         {
#             "roi": {
#                 "x": 252,
#                 "y": 126,
#                 "width": 37,
#                 "height": 37
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 260,
#                     "y": 137
#                 },
#                 "rightEye": {
#                     "x": 276,
#                     "y": 136
#                 },
#                 "nose": {
#                     "x": 268,
#                     "y": 143
#                 },
#                 "leftMouth": {
#                     "x": 262,
#                     "y": 153
#                 },
#                 "rightMouth": {
#                     "x": 276,
#                     "y": 152
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.762295
#             },
#             "age": {
#                 "value": "3~7",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.996311
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999858
#             }
#         },
#         {
#             "roi": {
#                 "x": 340,
#                 "y": 151,
#                 "width": 38,
#                 "height": 38
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 351,
#                     "y": 164
#                 },
#                 "rightEye": {
#                     "x": 367,
#                     "y": 163
#                 },
#                 "nose": {
#                     "x": 359,
#                     "y": 171
#                 },
#                 "leftMouth": {
#                     "x": 352,
#                     "y": 179
#                 },
#                 "rightMouth": {
#                     "x": 368,
#                     "y": 178
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.787069
#             },
#             "age": {
#                 "value": "1~5",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.998632
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.970677
#             }
#         },
#         {
#             "roi": {
#                 "x": 190,
#                 "y": 94,
#                 "width": 45,
#                 "height": 45
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 203,
#                     "y": 105
#                 },
#                 "rightEye": {
#                     "x": 222,
#                     "y": 105
#                 },
#                 "nose": {
#                     "x": 214,
#                     "y": 119
#                 },
#                 "leftMouth": {
#                     "x": 202,
#                     "y": 126
#                 },
#                 "rightMouth": {
#                     "x": 223,
#                     "y": 126
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999935
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.462804
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.843945
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998941
#             }
#         }
#     ]
# }

# %%
#############################################
#기분 문법
#############################################

# %%
#DICT형, Json에 대해

# %%
dict = {'Name' : 'pinkwink', 'Age' : 'None', 'Class' : ['beginner', 'blog'] }
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
#############################################
# Json
#############################################

# %%
customer = {
    'id' : '0001',
    'name' : '홍길동',
    'history' : [
        {'date' : '2019-03-01', 'log' : True},
        {'date' : '2019-03-02', 'log' : False}
    ]
}

# %%
import json
json_test = json.dumps(customer, indent=4, ensure_ascii=False)
print(json_test)
{
    "id" : "0001",
    "name" : "홍길동",
    "history" : [
        {
            'date' : '2019-03-01', 'log' : True
        }
        {
            'date' : '2019-03-02', 'log' : False
        }
    ]
}
# Out:
#   File "<ipython-input-25-8b09ec4bd3c0>", line 11
#     {
#     ^
# SyntaxError: invalid syntax

# %%
import requests  # 인터넷 연결

client_id = "kydsTfNDsk_rwx6JKIFn"
client_secret = "dkJvfxVCG_"

#얼굴정보
url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 600,
#             "height": 600
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 180,
#                 "y": 114,
#                 "width": 183,
#                 "height": 183
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 223,
#                     "y": 170
#                 },
#                 "rightEye": {
#                     "x": 303,
#                     "y": 144
#                 },
#                 "nose": {
#                     "x": 266,
#                     "y": 209
#                 },
#                 "leftMouth": {
#                     "x": 259,
#                     "y": 256
#                 },
#                 "rightMouth": {
#                     "x": 319,
#                     "y": 242
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999923
#             },
#             "age": {
#                 "value": "19~23",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999993
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.992922
#             }
#         }
#     ]
# }

# %%
parsed.keys() #parsed 는 보기 좋게 잘라줌
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces'][0]['roi'] # [0]은 사람번호
# Out:
# {'x': 180, 'y': 114, 'width': 183, 'height': 183}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'female', 'confidence': 0.999923}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '19~23', 'confidence': 1.0}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 0.999993}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " : " + str(age_confi) + '\n'

# %%
print(annotation)
# Out:
# female : 0.999923
# neutral : 0.999993
# 19~23 : 1.0

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')
#액자에 사진 올리는 법
fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                              linewidth = 5, 
                              edgecolor = 'r',
                              facecolor = 'none'
                             )
ax.add_patch(rect_face)

plt.text(10, 400, annotation, wrap = True, fontsize = 17, color = 'white')
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "kydsTfNDsk_rwx6JKIFn"
client_secret = "dkJvfxVCG_"

#얼굴정보
url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 600,
#             "height": 400
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 360,
#                 "y": 62,
#                 "width": 47,
#                 "height": 47
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 373,
#                     "y": 72
#                 },
#                 "rightEye": {
#                     "x": 393,
#                     "y": 73
#                 },
#                 "nose": {
#                     "x": 381,
#                     "y": 84
#                 },
#                 "leftMouth": {
#                     "x": 371,
#                     "y": 93
#                 },
#                 "rightMouth": {
#                     "x": 393,
#                     "y": 93
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 1.0
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.755652
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.887679
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999327
#             }
#         },
#         {
#             "roi": {
#                 "x": 252,
#                 "y": 126,
#                 "width": 37,
#                 "height": 37
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 260,
#                     "y": 137
#                 },
#                 "rightEye": {
#                     "x": 276,
#                     "y": 136
#                 },
#                 "nose": {
#                     "x": 268,
#                     "y": 143
#                 },
#                 "leftMouth": {
#                     "x": 262,
#                     "y": 153
#                 },
#                 "rightMouth": {
#                     "x": 276,
#                     "y": 152
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.762295
#             },
#             "age": {
#                 "value": "3~7",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.996311
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999858
#             }
#         },
#         {
#             "roi": {
#                 "x": 340,
#                 "y": 151,
#                 "width": 38,
#                 "height": 38
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 351,
#                     "y": 164
#                 },
#                 "rightEye": {
#                     "x": 367,
#                     "y": 163
#                 },
#                 "nose": {
#                     "x": 359,
#                     "y": 171
#                 },
#                 "leftMouth": {
#                     "x": 352,
#                     "y": 179
#                 },
#                 "rightMouth": {
#                     "x": 368,
#                     "y": 178
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.787069
#             },
#             "age": {
#                 "value": "1~5",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.998632
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.970677
#             }
#         },
#         {
#             "roi": {
#                 "x": 190,
#                 "y": 94,
#                 "width": 45,
#                 "height": 45
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 203,
#                     "y": 105
#                 },
#                 "rightEye": {
#                     "x": 222,
#                     "y": 105
#                 },
#                 "nose": {
#                     "x": 214,
#                     "y": 119
#                 },
#                 "leftMouth": {
#                     "x": 202,
#                     "y": 126
#                 },
#                 "rightMouth": {
#                     "x": 223,
#                     "y": 126
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999935
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.462804
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.843945
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998941
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)


for each in parsed['faces']:
    
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)     
    annotation = gender + " : " + str(round(gen_confi,3)*100) + "%" + '\n' + emotion + " : " + str(round(emo_confi,3)*100) + "%" +'\n' + age + " : " + str(round(age_confi,3)*100) + "%"
    plt.text(x-5, y-15, annotation, wrap = True, fontsize = 10, color = 'white')

plt.show()

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)



for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)    
    
    annotation = gender + " : " + str(round(gen_confi,2)*100)+'%' + '\n' + emotion + " : " + str(round(emo_confi,2)*100)+'%' + '\n' + age + " : " + str(round(age_confi,2)*100)+'%'
    plt.text(x-15, y-20, annotation, wrap=True, fontsize=10, color = 'white')
    
plt.show()
